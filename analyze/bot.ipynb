# %%
from IPython.display import SVG, display

# Create an SVG of a bot
svg_bot = '''
<svg width="100" height="110" xmlns="http://www.w3.org/2000/svg">
  <!-- Head -->
  <rect x="10" y="20" width="80" height="80" fill="#1176b0" stroke="#2E5C8A" stroke-width="2" rx="10"/>
  
  <!-- Eyes -->
  <circle cx="35" cy="50" r="8" fill="#FFF"/>
  <circle cx="65" cy="50" r="8" fill="#FFF"/>
  <circle cx="35" cy="50" r="4" fill="#000"/>
  <circle cx="65" cy="50" r="4" fill="#000"/>
  
  <!-- Antenna -->
  <line x1="50" y1="20" x2="50" y2="5" stroke="#2E5C8A" stroke-width="3"/>
  <circle cx="50" cy="5" r="5" fill="#E74C3C"/>
  
  <!-- Mouth -->
  <path d="M 35 75 Q 50 82 65 75" stroke="#2E5C8A" stroke-width="3" fill="none" stroke-linecap="round"/>
</svg>
'''

display(SVG(svg_bot))


# save to file
with open("figures/bot.svg", "w") as f:
    f.write(svg_bot)

# Create a black and white version
svg_bot_bw = '''
<svg width="100" height="110" xmlns="http://www.w3.org/2000/svg">
  <!-- Head -->
  <rect x="10" y="20" width="80" height="80" fill="#FFF" stroke="#000" stroke-width="2" rx="10"/>
  
  <!-- Eyes -->
  <circle cx="35" cy="50" r="8" fill="#000"/>
  <circle cx="65" cy="50" r="8" fill="#000"/>
  <circle cx="35" cy="50" r="4" fill="#FFF"/>
  <circle cx="65" cy="50" r="4" fill="#FFF"/>
  
  <!-- Antenna -->
  <line x1="50" y1="20" x2="50" y2="5" stroke="#000" stroke-width="3"/>
  <circle cx="50" cy="5" r="5" fill="#000"/>
  
  <!-- Mouth -->
  <path d="M 35 75 Q 50 82 65 75" stroke="#000" stroke-width="3" fill="none" stroke-linecap="round"/>
</svg>
'''

display(SVG(svg_bot_bw))

# save black and white version to file
with open("figures/bot_bw.svg", "w") as f:
    f.write(svg_bot_bw)
