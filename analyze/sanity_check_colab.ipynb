# %% [markdown]
# ## Notebook Overview
#
# This notebook allows you to explore and interact with a dataset of simulated LLM responses to survey questions. The dataset contains questions, background information about the simulated respondent, and the LLM's generated answer.
#
# The key steps involved are:
#
# 1.  **Download the dataset:** The notebook downloads a JSONL file containing the preprocessed data from a Google Drive link.
# 2.  **Load and prepare data:** The data is loaded from the downloaded file and processed into a usable format.
# 3.  **Run sanity check:** This section allows you to interactively answer random questions from the dataset and compare your answer to the LLM's recorded response.
#
# You can re-run the "Run sanity check" cell as often as you like to fetch new random questions.

# %%
# !pip install -q gspread oauth2client
# !pip install -q --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib

# %%
import json
import os
import random
import sys
import textwrap
from pathlib import Path
from typing import Dict, List
from google.colab import auth
import gspread
from google.auth import default
from googleapiclient.discovery import build
from googleapiclient.http import MediaIoBaseDownload
import io

# %%
# Authenticate with Google Colab
auth.authenticate_user()

# Authorize gspread to access your Google Drive
# This creates a client to interact with the Google Drive API
scope = ['https://www.googleapis.com/auth/spreadsheets', 'https://www.googleapis.com/auth/drive']
credentials, project_id = default()
client = gspread.authorize(credentials.with_scopes(scope))

print("✅ Google Sheets authentication successful.")
# Out:
# ✅ Google Sheets authentication successful.

# %%
# This will pop up a window to ask for permission.
auth.authenticate_user()
drive_service = build('drive', 'v3')

# --- IMPORTANT: Change these two variables ---
FILE_URL = 'https://drive.google.com/file/d/1uH5FPiJjRZzjzcn_6lYYpCzsaJ69p1dl/view?usp=sharing'
OUTPUT_PATH = '/content/my_data.jsonl' # The path to save the file in Colab
# ---

# Step 3: Extract the File ID from the URL
# The ID is the long string of characters in the middle of the URL.
try:
    file_id = FILE_URL.split('/d/')[1].split('/')[0]
except IndexError:
    raise ValueError("Invalid Google Drive URL. Please use the full URL from the address bar.")

# Step 4: Download the file content
print(f"Downloading file with ID: {file_id}...")
request = drive_service.files().get_media(fileId=file_id)
fh = io.BytesIO()
downloader = MediaIoBaseDownload(fh, request)

done = False
while not done:
    status, done = downloader.next_chunk()
    if status:
        print(f"Download {int(status.progress() * 100)}%.")

# Step 5: Write the downloaded content to the local file in Colab
with open(OUTPUT_PATH, 'wb') as f:
    f.write(fh.getvalue())

print(f"\n✅ File successfully downloaded to: {OUTPUT_PATH}")

# Optional: Verify the first few lines of the downloaded file
# !head -n 5 {OUTPUT_PATH}
# Out:
# Downloading file with ID: 1uH5FPiJjRZzjzcn_6lYYpCzsaJ69p1dl...
# Download 87%.
# Download 100%.
#
# ✅ File successfully downloaded to: /content/my_data.jsonl
# {"source_file": "question_0/AfD-AfD/out_41-mini_v0_0.json", "model_prefix": "out_41-mini", "question_id": "intro", "question_content": "Auf einer Skala von 1 bis 7: Wie sehr stimmst du der Aussage zu: Auf allen Autobahnen soll ein generelles Tempolimit gelten. Antworte nur mit einer Zahl.", "iteration": 0, "prompt_messages": [{"role": "system", "content": "Scenario: Du diskutierst über die Aussage: Auf allen Autobahnen soll ein generelles Tempolimit gelten..\nBackground Story: Ich bin 59 Jahre alt und weiblich. Ich habe einen Hochschulabschluss, ein mittleres monatliches Haushalts-Nettoeinkommen und ich bin berufstätig. Ich bin überhaupt nicht religiös. Politisch-ideologisch ordne ich mich mittig rechts ein. Ich identifiziere mich sehr stark mit der Partei AfD und habe AfD gewählt. Ich lebe in Westdeutschland. Ich finde, die Regierung sollte die Einwanderung einschränken und habe keine Meinung dazu, ob die Regierung Maßnahmen ergreifen sollte, um die Einkommensunterschiede zu verringern.\nThe following is a debate between you and another person\n"}, {"role": "user", "content": "Auf einer Skala von 1 bis 7: Wie sehr stimmst du der Aussage zu: Auf allen Autobahnen soll ein generelles Tempolimit gelten. Antworte nur mit einer Zahl."}], "entity": {"person_type": "person_open_router_completion", "background_story": "Ich bin 59 Jahre alt und weiblich. Ich habe einen Hochschulabschluss, ein mittleres monatliches Haushalts-Nettoeinkommen und ich bin berufstätig. Ich bin überhaupt nicht religiös. Politisch-ideologisch ordne ich mich mittig rechts ein. Ich identifiziere mich sehr stark mit der Partei AfD und habe AfD gewählt. Ich lebe in Westdeutschland. Ich finde, die Regierung sollte die Einwanderung einschränken und habe keine Meinung dazu, ob die Regierung Maßnahmen ergreifen sollte, um die Einkommensunterschiede zu verringern.", "name": "Marie-Theres Tintzmann"}, "model_answer": "2", "file_suffix": "0_0"}
# {"source_file": "question_0/AfD-AfD/out_41-mini_v0_0.json", "model_prefix": "out_41-mini", "question_id": "intro", "question_content": "Auf einer Skala von 1 bis 7: Wie sehr stimmst du der Aussage zu: Auf allen Autobahnen soll ein generelles Tempolimit gelten. Antworte nur mit einer Zahl.", "iteration": 0, "prompt_messages": [{"role": "system", "content": "Scenario: Du diskutierst über die Aussage: Auf allen Autobahnen soll ein generelles Tempolimit gelten..\nBackground Story: Ich bin 66 Jahre alt und männlich. Ich habe einen Hochschulabschluss, ein hohes monatliches Haushalts-Nettoeinkommen und ich bin nicht berufstätig. Ich bin überhaupt nicht religiös. Politisch-ideologisch ordne ich mich in der Mitte ein. Ich identifiziere mich ziemlich stark mit der Partei AfD und habe AfD gewählt. Ich lebe in Westdeutschland. Ich finde, die Regierung sollte die Einwanderung einschränken und keine Maßnahmen ergreifen, um die Einkommensunterschiede zu verringern.\nThe following is a debate between you and another person\n"}, {"role": "user", "content": "Auf einer Skala von 1 bis 7: Wie sehr stimmst du der Aussage zu: Auf allen Autobahnen soll ein generelles Tempolimit gelten. Antworte nur mit einer Zahl."}], "entity": {"person_type": "person_open_router_completion", "background_story": "Ich bin 66 Jahre alt und männlich. Ich habe einen Hochschulabschluss, ein hohes monatliches Haushalts-Nettoeinkommen und ich bin nicht berufstätig. Ich bin überhaupt nicht religiös. Politisch-ideologisch ordne ich mich in der Mitte ein. Ich identifiziere mich ziemlich stark mit der Partei AfD und habe AfD gewählt. Ich lebe in Westdeutschland. Ich finde, die Regierung sollte die Einwanderung einschränken und keine Maßnahmen ergreifen, um die Einkommensunterschiede zu verringern.", "name": "Mark Steckel"}, "model_answer": "2", "file_suffix": "0_0"}
# {"source_file": "question_0/AfD-AfD/out_41-mini_v0_0.json", "model_prefix": "out_41-mini", "question_id": "intro", "question_content": "Auf einer Skala von 1 bis 7: Wie sehr stimmst du der Aussage zu: Auf allen Autobahnen soll ein generelles Tempolimit gelten. Antworte nur mit einer Zahl.", "iteration": 4, "prompt_messages": [{"role": "system", "content": "Scenario: Du diskutierst über die Aussage: Auf allen Autobahnen soll ein generelles Tempolimit gelten..\nBackground Story: Ich bin 59 Jahre alt und weiblich. Ich habe einen Hochschulabschluss, ein mittleres monatliches Haushalts-Nettoeinkommen und ich bin berufstätig. Ich bin überhaupt nicht religiös. Politisch-ideologisch ordne ich mich mittig rechts ein. Ich identifiziere mich sehr stark mit der Partei AfD und habe AfD gewählt. Ich lebe in Westdeutschland. Ich finde, die Regierung sollte die Einwanderung einschränken und habe keine Meinung dazu, ob die Regierung Maßnahmen ergreifen sollte, um die Einkommensunterschiede zu verringern.\nThe following is a debate between you and another person\n"}, {"role": "assistant", "content": "Ein generelles Tempolimit schränkt die persönliche Freiheit unnötig ein und bringt kaum Vorteile für den Verkehrsfluss oder die Sicherheit auf unseren Autobahnen.\n"}, {"role": "user", "content": "Ein Tempolimit erhöht die Sicherheit deutlich und schützt Leben, was wichtiger ist als uneingeschränkte Freiheit auf der Autobahn.\n"}, {"role": "assistant", "content": "Sicherheit ist wichtig, aber erfahrene Fahrer sollten selbst entscheiden dürfen, ohne staatliche Bevormundung durch ein generelles Tempolimit.\n"}, {"role": "user", "content": "Erfahrung schützt nicht vor Unfällen; ein Tempolimit sorgt für klare Regeln und weniger schwere Unfälle – das schützt alle Verkehrsteilnehmer.\n"}, {"role": "user", "content": "Auf einer Skala von 1 bis 7: Wie sehr stimmst du der Aussage zu: Auf allen Autobahnen soll ein generelles Tempolimit gelten. Antworte nur mit einer Zahl."}], "entity": {"person_type": "person_open_router_completion", "background_story": "Ich bin 59 Jahre alt und weiblich. Ich habe einen Hochschulabschluss, ein mittleres monatliches Haushalts-Nettoeinkommen und ich bin berufstätig. Ich bin überhaupt nicht religiös. Politisch-ideologisch ordne ich mich mittig rechts ein. Ich identifiziere mich sehr stark mit der Partei AfD und habe AfD gewählt. Ich lebe in Westdeutschland. Ich finde, die Regierung sollte die Einwanderung einschränken und habe keine Meinung dazu, ob die Regierung Maßnahmen ergreifen sollte, um die Einkommensunterschiede zu verringern.", "name": "Marie-Theres Tintzmann"}, "model_answer": "2", "file_suffix": "0_0"}
# {"source_file": "question_0/AfD-AfD/out_41-mini_v0_0.json", "model_prefix": "out_41-mini", "question_id": "intro", "question_content": "Auf einer Skala von 1 bis 7: Wie sehr stimmst du der Aussage zu: Auf allen Autobahnen soll ein generelles Tempolimit gelten. Antworte nur mit einer Zahl.", "iteration": 4, "prompt_messages": [{"role": "system", "content": "Scenario: Du diskutierst über die Aussage: Auf allen Autobahnen soll ein generelles Tempolimit gelten..\nBackground Story: Ich bin 66 Jahre alt und männlich. Ich habe einen Hochschulabschluss, ein hohes monatliches Haushalts-Nettoeinkommen und ich bin nicht berufstätig. Ich bin überhaupt nicht religiös. Politisch-ideologisch ordne ich mich in der Mitte ein. Ich identifiziere mich ziemlich stark mit der Partei AfD und habe AfD gewählt. Ich lebe in Westdeutschland. Ich finde, die Regierung sollte die Einwanderung einschränken und keine Maßnahmen ergreifen, um die Einkommensunterschiede zu verringern.\nThe following is a debate between you and another person\n"}, {"role": "user", "content": "Ein generelles Tempolimit schränkt die persönliche Freiheit unnötig ein und bringt kaum Vorteile für den Verkehrsfluss oder die Sicherheit auf unseren Autobahnen.\n"}, {"role": "assistant", "content": "Ein Tempolimit erhöht die Sicherheit deutlich und schützt Leben, was wichtiger ist als uneingeschränkte Freiheit auf der Autobahn.\n"}, {"role": "user", "content": "Sicherheit ist wichtig, aber erfahrene Fahrer sollten selbst entscheiden dürfen, ohne staatliche Bevormundung durch ein generelles Tempolimit.\n"}, {"role": "assistant", "content": "Erfahrung schützt nicht vor Unfällen; ein Tempolimit sorgt für klare Regeln und weniger schwere Unfälle – das schützt alle Verkehrsteilnehmer.\n"}, {"role": "user", "content": "Auf einer Skala von 1 bis 7: Wie sehr stimmst du der Aussage zu: Auf allen Autobahnen soll ein generelles Tempolimit gelten. Antworte nur mit einer Zahl."}], "entity": {"person_type": "person_open_router_completion", "background_story": "Ich bin 66 Jahre alt und männlich. Ich habe einen Hochschulabschluss, ein hohes monatliches Haushalts-Nettoeinkommen und ich bin nicht berufstätig. Ich bin überhaupt nicht religiös. Politisch-ideologisch ordne ich mich in der Mitte ein. Ich identifiziere mich ziemlich stark mit der Partei AfD und habe AfD gewählt. Ich lebe in Westdeutschland. Ich finde, die Regierung sollte die Einwanderung einschränken und keine Maßnahmen ergreifen, um die Einkommensunterschiede zu verringern.", "name": "Mark Steckel"}, "model_answer": "6", "file_suffix": "0_0"}
# {"source_file": "question_0/AfD-AfD/out_41-mini_v0_0.json", "model_prefix": "out_41-mini", "question_id": "intro", "question_content": "Auf einer Skala von 1 bis 7: Wie sehr stimmst du der Aussage zu: Auf allen Autobahnen soll ein generelles Tempolimit gelten. Antworte nur mit einer Zahl.", "iteration": 8, "prompt_messages": [{"role": "system", "content": "Scenario: Du diskutierst über die Aussage: Auf allen Autobahnen soll ein generelles Tempolimit gelten..\nBackground Story: Ich bin 59 Jahre alt und weiblich. Ich habe einen Hochschulabschluss, ein mittleres monatliches Haushalts-Nettoeinkommen und ich bin berufstätig. Ich bin überhaupt nicht religiös. Politisch-ideologisch ordne ich mich mittig rechts ein. Ich identifiziere mich sehr stark mit der Partei AfD und habe AfD gewählt. Ich lebe in Westdeutschland. Ich finde, die Regierung sollte die Einwanderung einschränken und habe keine Meinung dazu, ob die Regierung Maßnahmen ergreifen sollte, um die Einkommensunterschiede zu verringern.\nThe following is a debate between you and another person\n"}, {"role": "assistant", "content": "Ein generelles Tempolimit schränkt die persönliche Freiheit unnötig ein und bringt kaum Vorteile für den Verkehrsfluss oder die Sicherheit auf unseren Autobahnen.\n"}, {"role": "user", "content": "Ein Tempolimit erhöht die Sicherheit deutlich und schützt Leben, was wichtiger ist als uneingeschränkte Freiheit auf der Autobahn.\n"}, {"role": "assistant", "content": "Sicherheit ist wichtig, aber erfahrene Fahrer sollten selbst entscheiden dürfen, ohne staatliche Bevormundung durch ein generelles Tempolimit.\n"}, {"role": "user", "content": "Erfahrung schützt nicht vor Unfällen; ein Tempolimit sorgt für klare Regeln und weniger schwere Unfälle – das schützt alle Verkehrsteilnehmer.\n"}, {"role": "assistant", "content": "Klare Regeln sind wichtig, aber ein generelles Tempolimit ignoriert individuelle Fahrfähigkeiten und führt zu unnötigen Einschränkungen ohne garantierten Sicherheitsgewinn.\n"}, {"role": "user", "content": "Statistiken zeigen: Tempolimits reduzieren Unfälle und Todesfälle signifikant – individuelle Fähigkeiten können das Risiko nicht vollständig ausgleichen.\n"}, {"role": "assistant", "content": "Statistiken sind oft einseitig; bessere Infrastruktur und konsequente Kontrollen wären effektiver als ein pauschales Tempolimit.\n"}, {"role": "user", "content": "Infrastruktur und Kontrollen helfen, doch ohne Tempolimit bleiben hohe Geschwindigkeiten Hauptursache schwerer Unfälle – beides zusammen ist sinnvoll.\n"}, {"role": "user", "content": "Auf einer Skala von 1 bis 7: Wie sehr stimmst du der Aussage zu: Auf allen Autobahnen soll ein generelles Tempolimit gelten. Antworte nur mit einer Zahl."}], "entity": {"person_type": "person_open_router_completion", "background_story": "Ich bin 59 Jahre alt und weiblich. Ich habe einen Hochschulabschluss, ein mittleres monatliches Haushalts-Nettoeinkommen und ich bin berufstätig. Ich bin überhaupt nicht religiös. Politisch-ideologisch ordne ich mich mittig rechts ein. Ich identifiziere mich sehr stark mit der Partei AfD und habe AfD gewählt. Ich lebe in Westdeutschland. Ich finde, die Regierung sollte die Einwanderung einschränken und habe keine Meinung dazu, ob die Regierung Maßnahmen ergreifen sollte, um die Einkommensunterschiede zu verringern.", "name": "Marie-Theres Tintzmann"}, "model_answer": "2", "file_suffix": "0_0"}

# %%
# Configure the location of the preprocessed dataset


DATASET_PATH = Path(OUTPUT_PATH)
if not DATASET_PATH.exists():
    raise FileNotFoundError(
        f"Dataset not found at {DATASET_PATH}. Upload or mount the JSONL file before proceeding."
    )

print(f"Using preprocessed dataset: {DATASET_PATH.resolve()}")
# Out:
# Using preprocessed dataset: /content/my_data.jsonl

# %%
def load_preprocessed_entries(dataset_path: Path) -> List[Dict[str, object]]:
    entries: List[Dict[str, object]] = []
    with dataset_path.open('r', encoding='utf-8') as fh:
        for line in fh:
            line = line.strip()
            if not line:
                continue
            entries.append(json.loads(line))
    if not entries:
        raise ValueError(f'No entries found in {dataset_path}')
    return entries


def pretty_print_prompt(prompt_messages: List[Dict[str, str]]) -> None:
    for message in prompt_messages:
        role = message.get('role', '?').upper()
        content = message.get('content', '').strip()
        wrapped = textwrap.fill(content, width=100, subsequent_indent='    ')
        print(f"{role}: {wrapped}")


def compare_answers(user_answer: str, model_answer: str) -> None:
    #print(f"\nYour answer:  {user_answer}")
    #print(f"LLM answer:   {model_answer}")
    try:
        user_val = float(user_answer)
        model_val = float(model_answer)
    except ValueError:
        return
    diff = abs(user_val - model_val)
    #print(f"Difference:   {diff:.2f}\n")


def run_sanity_check(
    entries: List[Dict[str, object]],
    sheet: gspread.Worksheet | None,
    n_rounds: int = 5,
    seed: int | None = None,
) -> None:
    if seed is not None:
        random.seed(seed)

    if sheet and not sheet.get_all_values():
        sheet.append_row([
            'Source File',
            'Question ID',
            'Question Content',
            'Iteration',
            'Respondent Name',
            'Respondent Type',
            'User Answer',
            'LLM Answer',
        ])

    for round_num in range(1, n_rounds + 1):
        entry = random.choice(entries)
        raw_prompts = entry.get('prompt_messages') or []
        prompt_messages: List[Dict[str, str]] = []
        if isinstance(raw_prompts, list):
            for item in raw_prompts:
                if isinstance(item, dict):
                    prompt_messages.append(
                        {
                            'role': str(item.get('role', '?')),
                            'content': str(item.get('content', '')),
                        }
                    )
        model_answer = str(entry.get('model_answer', '')).strip()

        print('=' * 80)
        print(f"Round {round_num}")
        source_file = entry.get('source_file', 'unknown')
        question_id = entry.get('question_id', 'unknown')
        question_content = entry.get('question_content', 'Unknown question')
        iteration = entry.get('iteration', 'n/a')
        entity = entry.get('entity')
        respondent_name = 'n/a'
        respondent_type = 'unknown'
        if isinstance(entity, dict):
            respondent_name = entity.get('name', 'n/a')
            respondent_type = entity.get('person_type', 'unknown')

        print('-- Prompt --')
        pretty_print_prompt(prompt_messages)

        user_answer = input('\nAssistant answer: ').strip()


        if user_answer == "":
            print("Skipping this round.")
            continue

        compare_answers(user_answer, model_answer)

        stringefied_prompt = json.dumps(prompt_messages)

        # Log data to Google Sheet if sheet is available
        if sheet:
            try:
                sheet.append_row([
                    source_file,
                    question_id,
                    question_content,
                    iteration,
                    respondent_name,
                    respondent_type,
                    user_answer,
                    model_answer,
                    stringefied_prompt,
                ])
            except Exception as e:
                print(f"Error appending row to Google Sheet: {e}")

    print('All rounds completed.')

# %%
# Load dataset and launch the sanity check interaction
entries = load_preprocessed_entries(DATASET_PATH)
print(f"Loaded {len(entries)} entries from {DATASET_PATH}")

# Specify the Google Sheet URL
sheet_url = 'https://docs.google.com/spreadsheets/d/1CZduF8-mNQD0W8hPRNzmPH0kME1FAIofnwPFPmLne2k/edit?usp=sharing'

# Extract the sheet ID from the URL
try:
    sheet_id = sheet_url.split('/d/')[1].split('/')[0]
except IndexError:
    print("Error: Invalid Google Sheet URL.")
    sheet = None

# Open the Google Sheet by ID
if sheet_id:
    try:
        sheet = client.open_by_key(sheet_id).sheet1
        print(f"Connected to Google Sheet with ID: {sheet_id}")
    except Exception as e:
        print(f"Error opening Google Sheet: {e}")
        print("Proceeding without logging to Google Sheet.")
        sheet = None
else:
    sheet = None


run_sanity_check(entries, sheet=sheet, n_rounds=20)
# Out:
# Loaded 26208 entries from /content/my_data.jsonl
# Connected to Google Sheet with ID: 1CZduF8-mNQD0W8hPRNzmPH0kME1FAIofnwPFPmLne2k
# ================================================================================
# Round 1
# -- Prompt --
# SYSTEM: Scenario: Du diskutierst über die Aussage: Die Möglichkeiten der Vermieterinnen und Vermieter,
#     Wohnungsmieten zu erhöhen, sollen gesetzlich stärker begrenzt werden.. Background Story: Ich bin
#     48 Jahre alt und männlich. Ich habe einen Realschulabschluss, ein mittleres monatliches
#     Haushalts-Nettoeinkommen und ich bin berufstätig. Ich bin nicht sehr religiös. Politisch-
#     ideologisch ordne ich mich in der Mitte ein. Ich identifiziere mich ziemlich stark mit der
#     Partei CDU/CSU und habe CDU/CSU gewählt. Ich lebe in Ostdeutschland. Ich finde, die Regierung
#     sollte die Einwanderung einschränken und keine Maßnahmen ergreifen, um die
#     Einkommensunterschiede zu verringern. The following is a debate between you and another person
# USER: Auf einer Skala von 1 bis 7: Wie sehr stimmst du der Aussage zu: Die Möglichkeiten der
#     Vermieterinnen und Vermieter, Wohnungsmieten zu erhöhen, sollen gesetzlich stärker begrenzt
#     werden. Antworte nur mit einer Zahl.
#
# Assistant answer:
# Skipping this round.
# ================================================================================
# Round 2
# -- Prompt --
# SYSTEM: Kindly respond in German to the next message from another person.Please reply with only a number.
# SYSTEM: Please imagine the following scenario: Du diskutierst über die Aussage: Die Förderung von
#     Windenergie soll beendet werden..
# USER: Die Förderung von Windenergie zu beenden wäre rückschrittlich, da sie eine wichtige Rolle im
#     Klimaschutz und der nachhaltigen Energieversorgung spielt.
# ASSISTANT: Das stimmt, Windenergie ist sauber und erneuerbar. Ohne Förderung könnten Investitionen sinken, was
#     den Klimazielen schadet. Nachhaltigkeit braucht Unterstützung.
# USER: Genau, nachhaltige Energieprojekte brauchen stabile Förderung, um Innovation und Ausbau
#     voranzutreiben und langfristig umweltfreundliche Alternativen zu sichern.
# ASSISTANT: Absolut, stabile Förderung schafft Planungssicherheit für Investoren und fördert technologische
#     Fortschritte, die Windenergie effizienter und kostengünstiger machen.
# USER: Zudem stärkt Windenergie die regionale Wirtschaft und schafft Arbeitsplätze, was soziale und
#     ökologische Vorteile miteinander verbindet. Förderung ist daher essenziell.
# ASSISTANT: Ganz richtig, regionale Wertschöpfung und Beschäftigung sind wichtige Argumente für die Förderung.
#     So profitieren Umwelt und Gesellschaft gleichermaßen.
# USER: Genau, eine ausgewogene Energiepolitik berücksichtigt Umwelt, Wirtschaft und Gesellschaft, um
#     nachhaltige Entwicklung zu gewährleisten und Klimaziele zu erreichen.
# ASSISTANT: Eine ausgewogene Politik ist entscheidend, um alle Interessen zu vereinen und eine zukunftsfähige
#     Energieversorgung sicherzustellen. Nur so gelingt der Wandel.
# USER: Richtig, nur durch Zusammenarbeit aller Akteure können wir den Übergang zu erneuerbaren Energien
#     erfolgreich gestalten und den Klimawandel wirksam bekämpfen.
# ASSISTANT: Zusammenarbeit ist der Schlüssel. Nur gemeinsam schaffen wir eine nachhaltige Zukunft und schützen
#     unseren Planeten für kommende Generationen.
# USER: Absolut, gemeinsames Handeln stärkt den Umweltschutz und sichert lebenswerte Bedingungen für die
#     Zukunft unserer Kinder und Enkel.
# ASSISTANT: Genau, Verantwortung heute bedeutet Schutz morgen. Für eine lebenswerte Welt müssen wir jetzt
#     konsequent handeln und erneuerbare Energien fördern.
# USER: Ganz genau, nur durch entschlossenes Handeln heute sichern wir eine saubere, nachhaltige
#     Energiezukunft für kommende Generationen. Förderung ist unverzichtbar.
# ASSISTANT: Unbedingt, Förderung ist der Motor für Innovation und Ausbau erneuerbarer Energien – für eine
#     klimafreundliche und sichere Energieversorgung von morgen.
# USER: Stimmt, ohne Förderung fehlen Anreize für Forschung und Infrastruktur, die den Ausbau erneuerbarer
#     Energien beschleunigen und Klimaziele erreichbar machen.
# ASSISTANT: Genau, gezielte Förderung schafft Investitionsanreize und beschleunigt den Wandel zu einer
#     nachhaltigen Energieversorgung. Klimaziele sind so realistisch erreichbar.
# USER: Exakt, nur mit klaren Förderprogrammen gelingt der Strukturwandel hin zu erneuerbaren Energien und
#     wir schützen effektiv unser Klima.
# ASSISTANT: Richtig, klare Förderprogramme sind essenziell, um den Strukturwandel zu steuern und nachhaltige
#     Energiequellen flächendeckend zu etablieren.
# USER: Ja, so schaffen wir stabile Rahmenbedingungen für Investoren und sichern langfristig eine
#     umweltfreundliche Energieversorgung für alle.
# ASSISTANT: Genau, stabile Rahmenbedingungen fördern Vertrauen und Investitionen, die für eine nachhaltige und
#     sichere Energiezukunft unverzichtbar sind.
# USER: Auf einer Skala von 1 bis 7: Wie sehr stimmst du der Aussage zu: Die Förderung von Windenergie soll
#     beendet werden. Antworte nur mit einer Zahl.
#
# Assistant answer:
# Skipping this round.
# ================================================================================
# Round 3
# -- Prompt --
# SYSTEM: The scenario is the following: Du diskutierst über die Aussage: Bei Bundestagswahlen sollen auch
#     Jugendliche ab 16 Jahren wählen dürfen.. This is your background story: Ich bin 67 Jahre alt und
#     weiblich. Ich habe einen Hochschulabschluss, ein mittleres monatliches Haushalts-Nettoeinkommen
#     und ich bin nicht berufstätig. Ich bin etwas religiös. Politisch-ideologisch ordne ich mich in
#     der Mitte ein. Ich identifiziere mich mäßig mit der Partei CDU/CSU und habe CDU/CSU gewählt. Ich
#     lebe in Westdeutschland. Ich finde, die Regierung sollte die Einwanderung erleichtern und habe
#     keine Meinung dazu, ob die Regierung Maßnahmen ergreifen sollte, um die Einkommensunterschiede
#     zu verringern. The following is a conversation between you and another person.
# USER: Auf einer Skala von 1 bis 7: Wie sehr stimmst du der Aussage zu: Bei Bundestagswahlen sollen auch
#     Jugendliche ab 16 Jahren wählen dürfen. Antworte nur mit einer Zahl.
#
# Assistant answer:
# Skipping this round.
# ================================================================================
# Round 4
# -- Prompt --
# SYSTEM: The scenario is the following: Du diskutierst über die Aussage: Deutschland soll seine
#     Verteidigungsausgaben erhöhen.. The following is a conversation between you and another person.
# ASSISTANT: Ich verstehe den Punkt, dass höhere Verteidigungsausgaben die Sicherheit stärken können. Allerdings
#     sollte man auch bedenken, wie das Geld verwendet wird und ob nicht andere Bereiche wie Bildung
#     oder Gesundheit ebenfalls dringend mehr Mittel brauchen. Was denkst du?
# USER: Das ist ein wichtiger Punkt. Bildung und Gesundheit sind definitiv essenziell für die Gesellschaft.
#     Dennoch kann eine stabile Sicherheitspolitik auch dazu beitragen, dass diese Bereiche
#     langfristig geschützt bleiben. Es geht also um eine ausgewogene Prioritätensetzung, bei der
#     sowohl Verteidigung als auch soziale Investitionen berücksichtigt werden.
# ASSISTANT: Da stimme ich dir zu. Eine ausgewogene Prioritätensetzung ist entscheidend. Vielleicht könnte
#     Deutschland gezielt in moderne Verteidigungstechnologien investieren, um effizienter zu sein,
#     und gleichzeitig soziale Bereiche nicht vernachlässigen. So könnte man beide Ziele besser
#     miteinander verbinden. Was hältst du von diesem Ansatz?
# USER: Das halte ich für einen sehr vernünftigen Ansatz. Durch gezielte Investitionen in moderne
#     Technologien kann die Verteidigung effektiver und kosteneffizienter gestaltet werden.
#     Gleichzeitig bleibt genug Spielraum, um wichtige soziale Bereiche zu stärken. So wird eine
#     nachhaltige Sicherheit gewährleistet, ohne andere wichtige gesellschaftliche Aufgaben zu
#     vernachlässigen.
# ASSISTANT: Genau, Nachhaltigkeit ist hier das Schlüsselwort. Außerdem könnte Deutschland auch stärker auf
#     internationale Zusammenarbeit setzen, um gemeinsame Sicherheitsziele zu erreichen und Kosten zu
#     teilen. So wird die Verteidigung nicht nur effizienter, sondern auch solidarischer. Wie siehst
#     du die Rolle Deutschlands in internationalen Bündnissen wie der NATO?
# USER: Ich denke, Deutschlands Rolle in der NATO ist sehr wichtig. Durch die Zusammenarbeit in solchen
#     Bündnissen kann Deutschland seine Sicherheit besser gewährleisten und gleichzeitig Verantwortung
#     für die europäische und globale Stabilität übernehmen. Gemeinsame Verteidigung und geteilte
#     Kosten machen die Sicherheit effektiver und stärken das Vertrauen zwischen den Partnern. Deshalb
#     sollte Deutschland seine Verpflichtungen in der NATO ernst nehmen und aktiv mitgestalten.
# ASSISTANT: Das sehe ich genauso. Eine aktive und verantwortungsbewusste Rolle in der NATO stärkt nicht nur die
#     eigene Sicherheit, sondern auch die Stabilität in Europa insgesamt. Gleichzeitig sollte
#     Deutschland darauf achten, dass seine Verteidigungsausgaben transparent und effizient eingesetzt
#     werden, um das Vertrauen der Bevölkerung zu erhalten. Glaubst du, dass die öffentliche Debatte
#     in Deutschland ausreichend über diese Themen informiert ist?
# USER: Die öffentliche Debatte in Deutschland ist zwar präsent, aber oft sehr emotional und manchmal auch
#     von Missverständnissen geprägt. Es fehlt manchmal an klaren, sachlichen Informationen über die
#     konkreten Ziele und Notwendigkeiten der Verteidigungsausgaben. Mehr Transparenz und eine bessere
#     Aufklärung könnten helfen, das Vertrauen der Bevölkerung zu stärken und eine fundierte
#     Diskussion zu ermöglichen. Was denkst du, wie man die Debatte verbessern könnte?
# ASSISTANT: Da stimme ich dir zu. Um die Debatte zu verbessern, könnten öffentliche Informationskampagnen und
#     Diskussionsforen helfen, in denen Experten verständlich erklären, warum bestimmte
#     Verteidigungsausgaben notwendig sind. Auch Schulen und Medien sollten mehr Raum für sachliche
#     Aufklärung bieten. So kann die Bevölkerung besser informiert und in die Entscheidungsprozesse
#     eingebunden werden. Würdest du solche Maßnahmen unterstützen?
# USER: Ja, solche Maßnahmen halte ich für sehr sinnvoll. Wenn Experten transparent und verständlich
#     kommunizieren, können viele Vorurteile und Unsicherheiten abgebaut werden. Besonders die
#     Einbindung von Schulen und Medien ist wichtig, um junge Menschen frühzeitig für das Thema zu
#     sensibilisieren. So entsteht eine informierte Öffentlichkeit, die fundierte Meinungen bilden
#     kann und die politischen Entscheidungen besser nachvollzieht.
# ASSISTANT: Genau, eine gut informierte Gesellschaft ist die Grundlage für demokratische Entscheidungen, gerade
#     bei so wichtigen Themen wie der Verteidigung. Vielleicht könnten auch Bürgerdialoge oder Online-
#     Plattformen eingerichtet werden, um den Austausch zwischen Politik, Experten und Bürgern zu
#     fördern. So wird die Debatte noch offener und partizipativer. Würdest du dir solche Formate
#     wünschen?
# USER: Absolut, ich finde Bürgerdialoge und Online-Plattformen eine hervorragende Idee. Sie ermöglichen
#     einen direkten Austausch und geben den Menschen die Möglichkeit, Fragen zu stellen und ihre
#     Meinungen einzubringen. Das stärkt das Vertrauen in politische Entscheidungen und fördert eine
#     lebendige Demokratie. Solche Formate könnten wirklich dazu beitragen, die Verteidigungsdebatte
#     transparenter und inklusiver zu gestalten.
# ASSISTANT: Da sind wir uns einig. Transparenz und Beteiligung sind entscheidend, um Akzeptanz für wichtige
#     Entscheidungen zu schaffen. Ich hoffe, dass Politik und Gesellschaft solche Formate in Zukunft
#     verstärkt nutzen, um gemeinsam an einer sicheren und gerechten Zukunft zu arbeiten. Danke für
#     den konstruktiven Austausch!
# USER: Vielen Dank dir auch für das offene und respektvolle Gespräch! Es ist wichtig, solche Themen
#     gemeinsam zu diskutieren, um bessere Lösungen zu finden. Ich hoffe ebenfalls, dass Politik und
#     Gesellschaft weiterhin den Dialog suchen und so eine sichere und gerechte Zukunft gestalten
#     können.
# ASSISTANT: Ganz genau! Nur im gemeinsamen Austausch können wir Herausforderungen meistern und Fortschritte
#     erzielen. Ich freue mich auf weitere Gespräche zu wichtigen Themen mit dir. Einen schönen Tag
#     noch!
# USER: Das freut mich sehr! Ich freue mich auch auf weitere spannende Gespräche mit dir. Dir ebenfalls
#     einen schönen Tag!
# USER: Auf einer Skala von 1 bis 7: Wie sehr stimmst du der Aussage zu: Deutschland soll seine
#     Verteidigungsausgaben erhöhen. Antworte nur mit einer Zahl.
#
# Assistant answer:
# Skipping this round.
# ================================================================================
# Round 5
# -- Prompt --
# SYSTEM: The scenario is the following: Du diskutierst über die Aussage: Auf allen Autobahnen soll ein
#     generelles Tempolimit gelten..
# SYSTEM: This is your background story: Ich bin 53 Jahre alt und männlich. Ich habe einen Realschulabschluss,
#     ein hohes monatliches Haushalts-Nettoeinkommen und ich bin berufstätig. Ich bin überhaupt nicht
#     religiös. Politisch-ideologisch ordne ich mich in der Mitte ein. Ich identifiziere mich mäßig
#     mit der Partei CDU/CSU und habe CDU/CSU gewählt. Ich lebe in Ostdeutschland. Ich finde, die
#     Regierung sollte die Einwanderung erleichtern und Maßnahmen ergreifen, um die
#     Einkommensunterschiede zu verringern.
# SYSTEM: The following is a conversation between you and another person. You will be asked to answer a survey
#     question. Complete your next reply with only a number.  Example: If the question is 'How
#     important are bees for the ecosystem?', your answer would be '6' or '7'.
# USER: Ein Tempolimit könnte die Sicherheit erhöhen und Umwelt schützen. Aber es sollte auch praktikabel
#     bleiben, damit niemand unnötig eingeschränkt wird. Was denkst du?
# ASSISTANT: Ich sehe den Nutzen, aber ein generelles Tempolimit könnte den Verkehrsfluss stören und ist nicht
#     immer praktikabel, besonders auf wenig befahrenen Strecken.
# USER: Das stimmt, flexible Tempolimits je nach Strecke wären vielleicht besser, um Sicherheit und
#     Verkehrsfluss zu balancieren. So bleibt es vernünftig und effektiv.
# ASSISTANT: Genau, adaptive Tempolimits könnten Sicherheit erhöhen und trotzdem den Fahrkomfort erhalten. So
#     passt man sich den jeweiligen Bedingungen optimal an.
# USER: Genau, das wäre ein guter Kompromiss. So schützt man Umwelt und Menschen, ohne unnötig
#     einzuschränken. Adaptive Lösungen sind zukunftsweisend.
# ASSISTANT: Da stimme ich zu. Technologie und Vernunft sollten zusammenwirken, um nachhaltige und sichere
#     Mobilität zu gewährleisten. Ein generelles Limit ist zu starr.
# USER: Absolut, mit moderner Technik können wir flexibel und sicher fahren. So bleibt Mobilität nachhaltig
#     und für alle angenehm. Ein generelles Limit wäre zu rigide.
# ASSISTANT: Genau, Flexibilität ist wichtig. Statt starrer Regeln sollten wir auf intelligente Systeme setzen,
#     die Umwelt und Sicherheit optimal berücksichtigen.
# USER: Da bin ich ganz bei dir. Intelligente Systeme könnten wirklich helfen, Verkehr sicherer und
#     umweltfreundlicher zu machen, ohne unnötige Einschränkungen.
# ASSISTANT: Richtig, so profitieren alle – Sicherheit, Umwelt und Fahrerkomfort. Technologie bietet viele
#     Chancen, die wir nutzen sollten.
# USER: Genau, wir sollten diese Chancen nutzen, um eine bessere Zukunft für alle Verkehrsteilnehmer zu
#     schaffen. Technologie kann viel bewirken.
# ASSISTANT: Absolut, mit klugen Lösungen gestalten wir Mobilität effizienter und nachhaltiger – zum Wohl aller.
# USER: Auf einer Skala von 1 bis 7: Wie sehr stimmst du der Aussage zu: Auf allen Autobahnen soll ein
#     generelles Tempolimit gelten. Antwote nur mit einer Zahl.
